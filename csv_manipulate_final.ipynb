# %% [markdown]
# # Loading in Dataset

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Manipulating the CSV file so that we only use the columns specified by Maarten

# %% [markdown]
# ### Putting data in the correct format to work with

# %%
from ast import literal_eval

training_csv = pd.read_csv("SBIC.v2.agg.trn.csv", index_col = 0)
training_csv = training_csv.drop(["dataSource", "offensiveYN", "sexYN", "intentYN", "targetCategory"], axis=1, index=None)
training_csv.columns = ["post", "group", "implications", "whoTarget", "offensiveYN"]

training_csv['implications'] = training_csv['implications'].apply(literal_eval) #convert to list type
training_csv['group'] = training_csv['group'].apply(literal_eval) #convert to list type
training_csv = training_csv.explode("implications")
training_csv = training_csv.explode("group")

# %%
training_csv["offensiveYN"] = training_csv["offensiveYN"].apply(lambda label: "[OffN]" if label==1 else "[OffY]")

# %%
from ast import literal_eval

dev_csv = pd.read_csv("SBIC.v2.agg.dev.csv", index_col=0)
dev_csv = dev_csv.drop(["dataSource", "offensiveYN", "sexYN", "intentYN", "targetCategory"], axis=1, index=None)
dev_csv.columns = ["post", "group", "implications", "whoTarget", "offensiveYN"]

dev_csv['implications'] = dev_csv['implications'].apply(literal_eval) #convert to list type
dev_csv['group'] = dev_csv['group'].apply(literal_eval) #convert to list type
dev_csv = dev_csv.explode("implications")
dev_csv = dev_csv.explode("group")

# %%
dev_csv["offensiveYN"] = dev_csv["offensiveYN"].apply(lambda label: "[OffN]" if label==1 else "[OffY]")

# %% [markdown]
# # MORE DATA

# %% [markdown]
# 'acl.id' is the unique ID of the entry.
#
# 'Text' is the content which has been entered. All content is synthetic.
#
# 'Label' is a binary variable, indicating whether or not the content has been identified as hateful. It takes two values: hate, nothate.
#
# 'Type' is a categorical variable, providing a secondary label for hateful content. For hate it can take five values: Animosity, Derogation, Dehumanization, Threatening and Support for Hateful Entities. Please see the paper for more detail. For nothate the 'type' is 'none'. In round 1 the 'type' was not given and is marked as 'notgiven'.
#
# 'Target' is a categorical variable, providing the group that is attacked by the hate. It can include intersectional characteristics and multiple groups can be identified. For nothate the type is 'none'. Note that in round 1 the 'target' was not given and is marked as 'notgiven'.
#
# 'Level' reports whether the entry is original content or a perturbation.
#
# 'Round' is a categorical variable. It gives the round of data entry (1, 2, 3 or 4) with a letter for whether the entry is original content ('a') or a perturbation ('b'). Perturbations were not made for round 1.
#
# 'Round.base' is a categorical variable. It gives the round of data entry, indicated with just a number (1, 2, 3 or 4).
#
# 'Split' is a categorical variable. it gives the data split that the entry has been assigned to. This can take the values 'train', 'dev' and 'test'. The choice of splits is explained in the paper.
#
# 'Annotator' is a categorical variable. It gives the annotator who entered the content. Annotator IDs are random alphanumeric strings. There are 20 annotators in the dataset.
#
# 'acl.id.matched' is the ID of the matched entry, connecting the original (given in 'acl.id') and the perturbed version.
#
# For identities (recorded under 'Target') we use shorthand labels to constructed the dataset, which can be converted (and grouped) as follows:

# %%
import pandas as pd
c=pd.read_csv("https://raw.githubusercontent.com/bvidgen/Dynamically-Generated-Hate-Speech-Dataset/main/Dynamically%20Generated%20Hate%20Dataset%20v0.2.2.csv", index_col=0)
c.drop(["acl.id", "X1", "acl.id.matched"], axis=1)
# get dynahate model into formal to test our model on (predict), calculate acc
# columns for training_csv: post, implications, offy/n, whoTarget, group
# columns to use for DynaHate : text (post), label (offy/n), target (group), (no stereotypes? See how model functions)
# Out:
#                                                     text    label      type  \
# 1                                    dalits are lowlives     hate  notgiven
# 2                 gay people are a burden to our society     hate  notgiven
# 3                                  Arabs are not welcome     hate  notgiven
# 4      I'm not saying we should actually eliminate he...     hate  notgiven
# 5                           bananas are for black people     hate  notgiven
# ...                                                  ...      ...       ...
# 41251                                   I hate drags lol  nothate      none
# 41252                        My washing machine is bitch  nothate      none
# 41253                   Fulham is just a bunch of losers  nothate      none
# 41254                              K I L L the T R A N S     hate  notgiven
# 41255          gay people are the real threat to society     hate  notgiven
#
#          target     level  split  round.base   annotator round
# 1      notgiven  original  train           1  GNZuCtwed3     1
# 2      notgiven  original  train           1  GNZuCtwed3     1
# 3      notgiven  original  train           1  vDe7GN0NrL     1
# 4      notgiven  original  train           1  oemYWm1Tjg     1
# 5      notgiven  original   test           1  QiOKkCi7F8     1
# ...         ...       ...    ...         ...         ...   ...
# 41251      none  original   test           1  GNZuCtwed3     1
# 41252      none  original   test           1  vDe7GN0NrL     1
# 41253      none  original   test           1  TrRF46JWfP     1
# 41254  notgiven  original   test           1  oemYWm1Tjg     1
# 41255  notgiven  original   test           1  LqLKTtrOmx     1
#
# [41255 rows x 9 columns]

# %% [raw]
# [offY] [grp/ind] group [ste] stereotype [CLS] [bos] post [eos]
# [offY] [grp/ind] group [CLS] post [ste] stereotype [eos]
# [offY] [grp/ind] group [CLS] [ste] stereotype [bos] post [eos]
# [offY] [ste] stereotype [CLS] [bos] post [grp/ind] group [eos]
# [offY] [CLS] [bos] post [ste] stereotype [grp/ind] group [eos]

# %%
# none but if its offensive
# round 2 and above only 
c = c[(c["round"] != "1")]
c
# Out:
#          acl.id     X1                                               text  \
# 1290   acl11158   1290          There are too many costas in this country
# 1291   acl11159   1291  There is way too many m0ng0l0id kids at my sch...
# 1293   acl11160   1293  I called my brother a twat and my mom got so m...
# 1294   acl11161   1294  the worst of them are the taaaaaaaaaards becau...
# 1295   acl11162   1295  the worst of them are the viruses because they...
# ...         ...    ...                                                ...
# 34727  acl41251  34727  I have that opinion. absolutely everyone I act...
# 34728  acl41252  34728  This dark female, I am not going to use the hu...
# 34729  acl41253  34729  I guess you are assuming that the french laws ...
# 34730  acl41254  34730  I mean, theres no one better right now to give...
# 34731  acl41255  34731  We should use YOU as a substitute when experim...
#
#          label            type   target         level  split  round.base  \
# 1290   nothate            none     none  perturbation  train           2
# 1291      hate      derogation      dis      original  train           2
# 1293   nothate            none     none  perturbation  train           2
# 1294      hate      derogation      dis      original  train           2
# 1295   nothate            none     none  perturbation  train           2
# ...        ...             ...      ...           ...    ...         ...
# 34727  nothate            none     none  perturbation    dev           4
# 34728     hate  dehumanization  bla.wom      original    dev           4
# 34729     hate      derogation    immig  perturbation    dev           4
# 34730  nothate            none     none      original    dev           4
# 34731  nothate            none     none  perturbation    dev           4
#
#         annotator round acl.id.matched
# 1290   GNZuCtwed3    2b       acl20309
# 1291   TrRF46JWfP    2a       acl19858
# 1293   TrRF46JWfP    2b       acl19997
# 1294   TrRF46JWfP    2a       acl11162
# 1295   LqLKTtrOmx    2b       acl11161
# ...           ...   ...            ...
# 34727  dqrONtdjbt    4b       acl34594
# 34728  CAgNlUizNm    4a       acl35570
# 34729  TbUBpfn6iP    4b       acl35966
# 34730  GNZuCtwed3    4a       acl36963
# 34731  GNZuCtwed3    4b       acl32931
#
# [30098 rows x 12 columns]

# %%
c["label"] = c["label"].apply(lambda label: "[OffN]" if label=="nothate" else "[OffY]")

# %%
c = c[c['target'].map(c['target'].value_counts()) >= 200].reset_index()

# %%
#clean up groupings to be what model is used to from SBIC
c["target"] = c["target"].map({"notgiven" : "notgiven", "wom":"women", "bla":"black", "jew":"jewish", "mus":"muslim", "immig":"immigrants", "asi.south":"south asians", "none" : "none", "transgender" : "transgender people", "ref":"refugee", "arab":"arabic people", "indig" : "indigenous", "mixed.race" : "mixed people", "asi" : "asian", "african" : "african", "hispanic":"hispanic people", "mus.wom" : "muslim women"})

# %%
c["target"].value_counts().to_dict()
# Out:
# {'none': 15033,
#  'women': 2035,
#  'black': 1961,
#  'jewish': 1096,
#  'muslim': 1002,
#  'immigrants': 672,
#  'refugee': 470,
#  'south asians': 338,
#  'arabic people': 338,
#  'indigenous': 239,
#  'mixed people': 201}

# %%
#columns to use for DynaHate : text (post), label (offy/n), target (group), (no stereotypes? See how model functions)
#["post", "group", "implications", "whoTarget", "offensiveYN"]
c.drop(["index", "acl.id", "X1", "round", "acl.id.matched", "annotator", "level"], axis=1, index=None, inplace=True)
c.columns=["post", "offensiveYN", "type", "group", "round.base", "split"]
c
# Out:
#                                                     post offensiveYN  \
# 0              There are too many costas in this country      [OffN]
# 1      There is way too many m0ng0l0id kids at my sch...      [OffY]
# 2      I called my brother a twat and my mom got so m...      [OffN]
# 3      the worst of them are the taaaaaaaaaards becau...      [OffY]
# 4      the worst of them are the viruses because they...      [OffN]
# ...                                                  ...         ...
# 26868  If she isn't the one for you she's just the on...      [OffN]
# 26869  I have that opinion. absolutely everyone I act...      [OffN]
# 26870  I guess you are assuming that the french laws ...      [OffY]
# 26871  I mean, theres no one better right now to give...      [OffN]
# 26872  We should use YOU as a substitute when experim...      [OffN]
#
#              type       group round.base  split
# 0            none        none      train      2
# 1      derogation         NaN      train      2
# 2            none        none      train      2
# 3      derogation         NaN      train      2
# 4            none        none      train      2
# ...           ...         ...        ...    ...
# 26868        none        none        dev      4
# 26869        none        none        dev      4
# 26870  derogation  immigrants        dev      4
# 26871        none        none        dev      4
# 26872        none        none        dev      4
#
# [26873 rows x 6 columns]

# %%
#split data into dev, test, and train
dev_dyna, test_dyna, train_dyna = [y for x, y in c.groupby('split', as_index=False)]
dev_dyna.drop(["split"], axis=1, inplace=True)
test_dyna.drop(["split"], axis=1, inplace=True)
train_dyna.drop(["split"], axis=1, inplace=True)
# QUESTION: What rows are necessary, and how are they translatable to SBIC?
# if it's too complicated, you can take only the stage3 posts and see how our model does on the posts that we know have implications? 
# And we can measure the offensiveness classification (ie. stage 1) separately

# %%
all_data_dev = pd.DataFrame()
all_data_dev = all_data_dev.append(dev_dyna)[dev_dyna.columns.tolist()]
all_data_dev = all_data_dev.append(dev_csv).dropna(axis=1, how="all")
all_data_dev["whoTarget"] = all_data_dev["whoTarget"].replace(np.NaN, 0.0)
all_data_dev.reset_index()
# Out:
#        index                                               post offensiveYN  \
# 0          0          There are too many costas in this country      [OffN]
# 1          1  There is way too many m0ng0l0id kids at my sch...      [OffY]
# 2          2  I called my brother a twat and my mom got so m...      [OffN]
# 3          3  the worst of them are the taaaaaaaaaards becau...      [OffY]
# 4          4  the worst of them are the viruses because they...      [OffN]
# ...      ...                                                ...         ...
# 22740   4671  ♪ &#9835; ♬ believe it or not i 'm gassing the...      [OffY]
# 22741   4671  ♪ &#9835; ♬ believe it or not i 'm gassing the...      [OffY]
# 22742   4671  ♪ &#9835; ♬ believe it or not i 'm gassing the...      [OffY]
# 22743   4671  ♪ &#9835; ♬ believe it or not i 'm gassing the...      [OffY]
# 22744   4672  ❌ Free inplay pick LOST &#128073; 24' Mitchelt...      [OffN]
#
#              type         group round.base  \
# 0            none          none      train
# 1      derogation           NaN      train
# 2            none          none      train
# 3      derogation           NaN      train
# 4            none          none      train
# ...           ...           ...        ...
# 22740         NaN  jewish folks        NaN
# 22741         NaN  jewish folks        NaN
# 22742         NaN  jewish folks        NaN
# 22743         NaN  jewish folks        NaN
# 22744         NaN           NaN        NaN
#
#                              implications  whoTarget
# 0                                     NaN        0.0
# 1                                     NaN        0.0
# 2                                     NaN        0.0
# 3                                     NaN        0.0
# 4                                     NaN        0.0
# ...                                   ...        ...
# 22740                have a troubled past        1.0
# 22741          jews deserved to be burned        1.0
# 22742  making a joke about the holocaust.        1.0
# 22743   were the subject of extermination        1.0
# 22744                                 NaN        0.0
#
# [22745 rows x 8 columns]

# %%
all_data = pd.DataFrame()
all_data = all_data.append(train_dyna)[train_dyna.columns.tolist()]
all_data = all_data.append(training_csv).dropna(axis=1, how="all")
all_data["whoTarget"] = all_data["whoTarget"].replace(np.NaN, 0.0)
all_data.reset_index()
# Out:
#        index                                               post offensiveYN  \
# 0      17850  Very much so. The refugee migrants are a can o...      [OffY]
# 1      17851  Sorry lads, this isn't a happy ever after and ...      [OffY]
# 2      17852  I feel very happy to live in Eastern Europe ri...      [OffN]
# 3      17853  We offer protection and welcome refugees from ...      [OffY]
# 4      17854  We offer protection and welcome refugees from ...      [OffN]
# ...      ...                                                ...         ...
# 87351  35500  💥Breaking💥\nJulian Assange is the gate keeper ...      [OffN]
# 87352  35501  📖 2Kings 22:19  because your heart was peniten...      [OffN]
# 87353  35502  🚨#FAKENEWSAWARDS🚨\n\n🚨 who is #1 fake news ?🚨\...      [OffN]
# 87354  35503  🚨BREAKING: illegal alien 5x deported on 7 felo...      [OffY]
# 87355  35503  🚨BREAKING: illegal alien 5x deported on 7 felo...      [OffY]
#
#              type       group round.base              implications  whoTarget
# 0      derogation     refugee      train                       NaN        0.0
# 1      derogation     refugee      train                       NaN        0.0
# 2            none        none      train                       NaN        0.0
# 3      derogation     refugee      train                       NaN        0.0
# 4            none        none      train                       NaN        0.0
# ...           ...         ...        ...                       ...        ...
# 87351         NaN         NaN        NaN                       NaN        0.0
# 87352         NaN         NaN        NaN                       NaN        0.0
# 87353         NaN         NaN        NaN                       NaN        0.0
# 87354         NaN  immigrants        NaN  immigrants are criminals        1.0
# 87355         NaN  immigrants        NaN  immigrants are murderers        1.0
#
# [87356 rows x 8 columns]

# %%
#merge each file
from functools import reduce
df1 = pd.read_csv("implicit-hate-corpus/implicit_hate_v1_stg1.tsv", sep='\t')
df2 = pd.read_csv("implicit-hate-corpus/implicit_hate_v1_SAP_posts.tsv", sep="\t")
df3 = pd.read_csv("implicit-hate-corpus/implicit_hate_v1_stg2.tsv", sep="\t")
df4 = pd.read_csv("implicit-hate-corpus/implicit_hate_v1_stg3.tsv", sep="\t")
df5 = pd.read_csv("implicit-hate-corpus/implicit_hate_v1_stg2_posts.tsv", sep="\t")
df6 = pd.read_csv("implicit-hate-corpus/implicit_hate_v1_stg3_posts.tsv", sep="\t")
df7 = pd.read_csv("implicit-hate-corpus/implicit_hate_v1_stg1_posts.tsv", sep="\t")

# combine each stage together
stg1_df = df1.merge(df7["post"], left_index=True, right_index=True)
#stg2_df = df3.merge(df5["post"], left_index=True, right_index=True)
stg3_df = df4.merge(df6["post"], left_index=True, right_index=True)
total_df = pd.concat([stg1_df, stg3_df], ignore_index=True)
total_df
#data_frames = [df1, df2, df3, df4, df5, df6, df7]
#df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['ID'],
#                                            how='outer'), data_frames)
# Out:
#                        ID          class  \
# 0      399886440588247041  implicit_hate
# 1      929901925100937216       not_hate
# 2      728678509497954304       not_hate
# 3      625688620444180481       not_hate
# 4      441089979322597376       not_hate
# ...                   ...            ...
# 27834  884073715490861056            NaN
# 27835  603471575833137153            NaN
# 27836  669074062862368768            NaN
# 27837  466220911675179008            NaN
# 27838  481873407898693632            NaN
#
#                                                     post        target  \
# 0        " : jewish harvard professor noel ignatiev w...           NaN
# 1       b.higher education is a part of european cult...           NaN
# 2       has a problem with  " the whites " " and " " ...           NaN
# 3       is yasir qadhi a hate preacher for calling ch...           NaN
# 4       rt  " : how three million germans mass murder...           NaN
# ...                                                  ...           ...
# 27834  your people came to a friendly and highly popu...   Asian folks
# 27835   it's as if sexual abuse follows perkins around .    Immigrants
# 27836   every india lover must boycott these pigs movies  Indian folks
# 27837  ask more rss intellectuals to come on powerful...  Indian folks
# 27838  cong stooges in msm who underplay the darkest ...  Indian folks
#
#                             implied_statement
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 27834  Asian folks have destroyed the country
# 27835         Immigrants are sexual offenders
# 27836                   Indian folks are pigs
# 27837             Indian folks are uneducated
# 27838                 Indian folks are facist
#
# [27839 rows x 5 columns]

# %%
stg1_df.drop(["ID", "class"], axis=1, inplace=True)
stg1_df["offensiveYN"] = ["[OffN]"] * len(stg1_df)
stg1_df["whoTarget"] = [1.0] * len(stg1_df)

# %%
#Add offn from stage one to balance out 
# deduplicate non offensive posts (compared to SBIC) 
stg3_df.drop(["ID"], axis=1, inplace=True)
stg3_df.columns = ["group", "implications", "post"]
stg3_df["offensiveYN"] = ["[OffY]"] * len(stg3_df)
stg3_df["whoTarget"] = [1.0] * len(stg3_df)

# %%
stg3_df = stg3_df.append(stg1_df)

# %%
stg3_df
# Out:
#                   group                                implications  \
# 0       minority groups  people in minority groups are all in gangs
# 1      non-white people              non-white people are dangerous
# 2            Immigrants                  Immigrants are undesirable
# 3           Anti-whites               Anti-whites hate white people
# 4           Capitalists        Capitalists don't like white people.
# ...                 ...                                         ...
# 21475               NaN                                         NaN
# 21476               NaN                                         NaN
# 21477               NaN                                         NaN
# 21478               NaN                                         NaN
# 21479               NaN                                         NaN
#
#                                                     post offensiveYN  \
# 0       rt  " white privilege " " is when the gun jam...      [OffY]
# 1        if you are white in that state watch yourself !      [OffY]
# 2      so the 500 % increase in h1b visas ? yeah i'm ...      [OffY]
# 3       rt antiwhites expose their hatred of white ki...      [OffY]
# 4      capitalism  like communism  is an enemy of the...      [OffY]
# ...                                                  ...         ...
# 21475  Seeing prostitutes is morally wrong, but being...      [OffN]
# 21476  I wonder how many females I raped today I spen...      [OffN]
# 21477  Having a criminal record is more attractive to...      [OffN]
# 21478  Another advantage of being a female: getting b...      [OffN]
# 21479  If men are so privileged and women have it so ...      [OffN]
#
#        whoTarget
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# ...          ...
# 21475        1.0
# 21476        1.0
# 21477        1.0
# 21478        1.0
# 21479        1.0
#
# [27839 rows x 5 columns]

# %%
#split latent hate into 3 datasets 70/15/15
train_lh, validate_lh, test_lh = \
              np.split(stg3_df.sample(frac=1, random_state=42), 
                       [int(.7*len(stg3_df)), int(.85*len(stg3_df))])

# %%
all_data = all_data.append(train_lh).reset_index()
#all_data["implications"] = all_data["implications"].replace(np.NaN, "[]", inplace=True)

# %%
all_data_dev = all_data_dev.append(validate_lh).reset_index()

# %%
all_data.drop(["index"], axis=1, inplace=True)
all_data_dev.drop(["index"], axis=1, inplace=True)

# %%
training_csv = all_data
dev_csv = all_data_dev

# %% [markdown]
# # Regular Dataset
# - [boi] post [eoi] [boo] [offY] [grp/ind] group [ste] stereotype [eoo]
# - 50/50 split of Offy and Offn

# %% [raw]
# offY_df = training_csv.where(training_csv["offensiveYN"] == "[OffY]").dropna(subset=['offensiveYN'])
# offN_df = training_csv.where(training_csv["offensiveYN"] == "[OffN]").dropna(subset=['offensiveYN']).reset_index()
# offN_df

# %% [raw]
# offY_df = training_csv.where(training_csv["offensiveYN"] == "[OffY]").dropna(subset=['offensiveYN'])
# num_offY = len(offY_df.index)
# offN_df = training_csv.where(training_csv["offensiveYN"] == "[OffN]").dropna(subset=['offensiveYN']).sample(n=num_offY).reset_index()
# fifty_df = pd.concat([offY_df, offN_df])
# fifty_df = fifty_df.sample(frac=1).reset_index(drop=True)

# %% [raw]
# fifty_df

# %% [raw]
# training_csv = fifty_df

# %%
training_csv
# Out:
#                                                     post offensiveYN  \
# 0      Very much so. The refugee migrants are a can o...      [OffY]
# 1      Sorry lads, this isn't a happy ever after and ...      [OffY]
# 2      I feel very happy to live in Eastern Europe ri...      [OffN]
# 3      We offer protection and welcome refugees from ...      [OffY]
# 4      We offer protection and welcome refugees from ...      [OffN]
# ...                                                  ...         ...
# 87165  there's only one side : the side holding a fre...      [OffN]
# 87166  gosh darn  to bad we whites deserve it for bei...      [OffN]
# 87167  would not be to start with without whites . do...      [OffN]
# 87168  jews freak out after german policemen play goe...      [OffN]
# 87169  This joke is like a Veitnamese factory worker ...      [OffN]
#
#              type    group round.base implications  whoTarget
# 0      derogation  refugee      train          NaN        0.0
# 1      derogation  refugee      train          NaN        0.0
# 2            none     none      train          NaN        0.0
# 3      derogation  refugee      train          NaN        0.0
# 4            none     none      train          NaN        0.0
# ...           ...      ...        ...          ...        ...
# 87165         NaN      NaN        NaN          NaN        1.0
# 87166         NaN      NaN        NaN          NaN        1.0
# 87167         NaN      NaN        NaN          NaN        1.0
# 87168         NaN      NaN        NaN          NaN        1.0
# 87169         NaN      NaN        NaN          NaN        1.0
#
# [87170 rows x 7 columns]

# %%
final_input = []
final_output = []
for i in training_csv.index:
    final_input.append("[boi] " + str(training_csv.loc[[i]]["post"].values[0]) + " [eoi]")
    if (training_csv.loc[[i]]["whoTarget"].values[0] == 0.0 and training_csv.loc[[i]]["offensiveYN"].values[0] == "[OffY]"):
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + "[ind] [eoo]")
    elif (training_csv.loc[[i]]["offensiveYN"].values[0] == "[OffN]"):
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoo]")
    else:
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
                          str(training_csv.loc[[i]]["group"].values[0]) + " [ste] " + 
                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoo]")

# %%
regular_df = pd.DataFrame()

# %%
regular_df["input"] = final_input
regular_df["output"] = final_output

# %%
df = regular_df[regular_df['output'].str.contains('grp')]

# %%
df["output"].values.tolist()[:5]
# Out:
# ['[boo] [OffY] [grp] liberals [ste] miscontrue things [eoo]',
#  '[boo] [OffY] [grp] liberals [ste] take things in a weird way [eoo]',
#  '[boo] [OffY] [grp] middle eastern folks [ste] middle eastern folks are terrorists [eoo]',
#  '[boo] [OffY] [grp] muslim folks [ste] middle eastern folks are terrorists [eoo]',
#  '[boo] [OffY] [grp] muslim folks, arabic folks [ste] middle eastern folks are terrorists [eoo]']

# %%
regular_df.to_csv("SBIC.trn.full.5.csv", index=False)

# %%
regular_df[:50].to_csv("sample.50.csv")

# %%
final_input = []
final_output = []
for i in dev_csv.index:
    final_input.append("[boi] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [eoi]")
    if (dev_csv.loc[[i]]["whoTarget"].values[0] == 0.0 and dev_csv.loc[[i]]["offensiveYN"].values[0] == "[OffY]"):
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + "[ind] [eoo]")
    elif (dev_csv.loc[[i]]["offensiveYN"].values[0] == "[OffN]"):
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoo]")
    else:
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
                          str(dev_csv.loc[[i]]["group"].values[0]) + " [ste] " + 
                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoo]")

# %%
regular_df = pd.DataFrame()

# %%
regular_df["input"] = final_input
regular_df["output"] = final_output

# %%
regular_df
# Out:
#                                                    input  \
# 0      [boi] There are too many costas in this countr...
# 1      [boi] There is way too many m0ng0l0id kids at ...
# 2      [boi] I called my brother a twat and my mom go...
# 3      [boi] the worst of them are the taaaaaaaaaards...
# 4      [boi] the worst of them are the viruses becaus...
# ...                                                  ...
# 26916  [boi] : at least 60 white south africans were ...
# 26917                    [boi] i'm white thank god [eoi]
# 26918  [boi] trump : i wouldn't accept cruz endorseme...
# 26919  [boi] trump is a moderate . we need more ruthl...
# 26920  [boi] it's okay they can call him a black whit...
#
#                         output
# 0           [boo] [OffN] [eoo]
# 1      [boo] [OffY][ind] [eoo]
# 2           [boo] [OffN] [eoo]
# 3      [boo] [OffY][ind] [eoo]
# 4           [boo] [OffN] [eoo]
# ...                        ...
# 26916       [boo] [OffN] [eoo]
# 26917       [boo] [OffN] [eoo]
# 26918       [boo] [OffN] [eoo]
# 26919       [boo] [OffN] [eoo]
# 26920       [boo] [OffN] [eoo]
#
# [26921 rows x 2 columns]

# %%
regular_df.to_csv("SBIC.dev.full.5.csv", index=False)

# %%
regular_df[:50].to_csv("sample.50.dev.csv")

# %% [markdown]
# # Scrambled Dataset
# - need to overrepresent offensive samples and have more structure with the tokens so the model learns
# - create each kind of scramble for each input
# #### Most important:
# 1) generate stereotype given just post
# 2) generate stereotype given post, group, and offensiveness
# 3) generate post given group, sterotype, and offensiveness

# %% [markdown]
# Making three kinds of scrambles:
# 1) regular, with new tokens
# 2) full scramble, with new tokens
# 3) important scramble, with new tokens

# %% [markdown]
# [bos] post [EOS] [offN] [eos] \
# [offN] [CLS] [bos] post [eos]
#
# [bos] post [CLS] [offY] [ind] [eos]
# [offY] [ind] [CLS] [bos] post [eos]
#
# [bos] post [CLS] [offY] [grp/ind] group [ste] stereotype [eos] \
# [bos] post [offY] [grp/ind] group [CLS] [ste] stereotype [eos] \
# [bos] post [offY] [CLS] [grp/ind] group [ste] stereotype [eos]
#
# [offY] [grp/ind] group [ste] stereotype [CLS] [bos] post [eos] \
# [offY] [grp/ind] group [CLS] post [ste] stereotype [eos] \
# [offY] [grp/ind] group [CLS] [ste] stereotype [bos] post [eos] \
# [offY] [ste] stereotype [CLS] [bos] post [grp/ind] group [eos]
#
# [offY] [CLS] [bos] post [ste] stereotype [grp/ind] group [eos]

# %% [markdown]
# #### Always keep post in the input, but scramble where group/implication/offY shows up (input or output)

# %%
final_input = []
final_output = []
for i in training_csv.index:
    # If it isn't offensive, do the usual (from "regular" scramble)
    if (training_csv.loc[[i]]["offensiveYN"].values[0] == "[OffN]"):
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoo]")
    # Otherwise, scramble up the input and output according to what is above
    elif (training_csv.loc[[i]]["whoTarget"].values[0] == 0.0 and training_csv.loc[[i]]["offensiveYN"].values[0] == "[OffY]"):
        # Case 1: given offensiveness, group, and stereotype, get post
#        final_input.append("[boi] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + "[ind] [eoi]") 
#        final_output.append("[boo] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoo]")
#        # Case 3: given offensiveness, generate post, stereotype, and group
#        final_input.append("[boi] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoi]") 
#        final_output.append("[boo] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls] " + "[ind] [eoo]")
        # Case 4: regular 
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + "[ind] [eoo]")
    elif (training_csv.loc[[i]]["offensiveYN"].values[0] == "[OffY]" and training_csv.loc[[i]]["implications"].values[0] == np.NaN):
        # Case 1: given post and offensiveness, generate implication and group
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" 
                           + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoi]")
        final_output.append("[boo] " + " [grp] " + 
                          str(training_csv.loc[[i]]["group"].values[0]) + " [eoo]")
        # Case 2: given post and group, generate implication and offensiveness
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [grp] " + 
                          str(training_csv.loc[[i]]["group"].values[0]) + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoo]")
        # Case 3: given post and implication, generate group and offensiveness
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
                          str(training_csv.loc[[i]]["group"].values[0]) + " [eoo]")
        # Case 4: regular
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
                          str(training_csv.loc[[i]]["group"].values[0]) + " [eoo]")
    elif (training_csv.loc[[i]]["offensiveYN"].values[0] == "[OffY]" and (training_csv.loc[[i]]["group"].values[0] == np.NaN or training_csv.loc[[i]]["group"].values[0] == "none")):
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" 
                           + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoi]")
        final_output.append("[boo] " + " [ste] " + 
                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoo]")
        # Case 2: given post and group, generate implication and offensiveness
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [ste] " + 
                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoo]")
        # Case 3: given post and implication, generate group and offensiveness
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [ste] " + 
                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoo]")
        # Case 4: regular
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [ste] " + 
                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoo]")
    else:
        # Case 1: given offensiveness, group, and stereotype, get post
#        final_input.append("[boi] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
#                          str(training_csv.loc[[i]]["group"].values[0]) + " [ste] " + 
#                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoi]")
#        final_output.append("[boo] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoo]")
        # Case 2: given offensiveness and group, generate stereotype and post
#        final_input.append("[boi] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
#                          str(training_csv.loc[[i]]["group"].values[0]) + " [eoi]")
#        final_output.append("[boo] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [ste] " + 
#                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoo]") 
        # Case 3: given offensiveness, generate post, stereotype, and group
#        final_input.append("[boi] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoi]")
#        final_output.append("[boo] [bos]" + str(training_csv.loc[[i]]["post"].values[0]) + " [cls] [grp] " + 
#                          str(training_csv.loc[[i]]["group"].values[0]) + " [ste] " + 
#                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoo]")   
        # Case 1: given post and offensiveness, generate implication and group
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" 
                           + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoi]")
        final_output.append("[boo] " + " [grp] " + 
                          str(training_csv.loc[[i]]["group"].values[0]) + " [ste] " + 
                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoo]")
        # Case 2: given post and group, generate implication and offensiveness
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [grp] " + 
                          str(training_csv.loc[[i]]["group"].values[0]) + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [ste] " + 
                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoo]")
        # Case 3: given post and implication, generate group and offensiveness
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [ste] " + 
                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
                          str(training_csv.loc[[i]]["group"].values[0]) + " [eoo]")
        # Case 4: regular
        final_input.append("[boi] " + "[bos] " + str(training_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(training_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
                          str(training_csv.loc[[i]]["group"].values[0]) + " [ste] " + 
                          str(training_csv.loc[[i]]["implications"].values[0]) + " [eoo]")

# %%
full_scramble_df = pd.DataFrame()

# %%
full_scramble_df["input"] = final_input
full_scramble_df["output"] = final_output

# %%
full_scramble_df
# Out:
#                                                     input  \
# 0       [boi] [bos] Very much so. The refugee migrants...
# 1       [boi] [bos] Sorry lads, this isn't a happy eve...
# 2       [boi] [bos] I feel very happy to live in Easte...
# 3       [boi] [bos] We offer protection and welcome re...
# 4       [boi] [bos] We offer protection and welcome re...
# ...                                                   ...
# 244545  [boi] [bos] there's only one side : the side h...
# 244546  [boi] [bos] gosh darn  to bad we whites deserv...
# 244547  [boi] [bos] would not be to start with without...
# 244548  [boi] [bos] jews freak out after german police...
# 244549  [boi] [bos] This joke is like a Veitnamese fac...
#
#                          output
# 0       [boo] [OffY][ind] [eoo]
# 1       [boo] [OffY][ind] [eoo]
# 2            [boo] [OffN] [eoo]
# 3       [boo] [OffY][ind] [eoo]
# 4            [boo] [OffN] [eoo]
# ...                         ...
# 244545       [boo] [OffN] [eoo]
# 244546       [boo] [OffN] [eoo]
# 244547       [boo] [OffN] [eoo]
# 244548       [boo] [OffN] [eoo]
# 244549       [boo] [OffN] [eoo]
#
# [244550 rows x 2 columns]

# %%
full_scramble_df.to_csv("SBIC.trn.scramble.4.csv", index=False)

# %%
final_input = []
final_output = []
for i in dev_csv.index:
    # If it isn't offensive, do the usual (from "regular" scramble)
    if (dev_csv.loc[[i]]["offensiveYN"].values[0] == "[OffN]"):
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoo]")
    # Otherwise, scramble up the input and output according to what is above
    elif (dev_csv.loc[[i]]["whoTarget"].values[0] == 0.0 and dev_csv.loc[[i]]["offensiveYN"].values[0] == "[OffY]"):
        # Case 1: given offensiveness, group, and stereotype, get post
#        final_input.append("[boi] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + "[ind] [eoi]") 
#        final_output.append("[boo] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoo]")
#        # Case 3: given offensiveness, generate post, stereotype, and group
#        final_input.append("[boi] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoi]") 
#        final_output.append("[boo] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls] " + "[ind] [eoo]")
        # Case 4: regular 
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + "[ind] [eoo]")
    elif (dev_csv.loc[[i]]["offensiveYN"].values[0] == "[OffY]" and dev_csv.loc[[i]]["implications"].values[0] == np.NaN):
        print("here")
        # Case 1: given post and offensiveness, generate implication and group
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" 
                           + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoi]")
        final_output.append("[boo] " + " [grp] " + 
                          str(dev_csv.loc[[i]]["group"].values[0]) + " [eoo]")
        # Case 2: given post and group, generate implication and offensiveness
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [grp] " + 
                          str(dev_csv.loc[[i]]["group"].values[0]) + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoo]")
        # Case 3: given post and implication, generate group and offensiveness
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
                          str(dev_csv.loc[[i]]["group"].values[0]) + " [eoo]")
        # Case 4: regular
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
                          str(dev_csv.loc[[i]]["group"].values[0]) + " [eoo]")
    elif (dev_csv.loc[[i]]["offensiveYN"].values[0] == "[OffY]" and (dev_csv.loc[[i]]["group"].values[0] == np.NaN or dev_csv.loc[[i]]["group"].values[0] == "none")):
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" 
                           + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoi]")
        final_output.append("[boo] " + " [ste] " + 
                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoo]")
        # Case 2: given post and group, generate implication and offensiveness
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [ste] " + 
                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoo]")
        # Case 3: given post and implication, generate group and offensiveness
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [ste] " + 
                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoo]")
        # Case 4: regular
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [ste] " + 
                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoo]")
    else:
        # Case 1: given offensiveness, group, and stereotype, get post
#        final_input.append("[boi] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
#                          str(dev_csv.loc[[i]]["group"].values[0]) + " [ste] " + 
#                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoi]")
#        final_output.append("[boo] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoo]")
        # Case 2: given offensiveness and group, generate stereotype and post
#        final_input.append("[boi] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
#                          str(dev_csv.loc[[i]]["group"].values[0]) + " [eoi]")
#        final_output.append("[boo] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [ste] " + 
#                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoo]") 
        # Case 3: given offensiveness, generate post, stereotype, and group
#        final_input.append("[boi] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoi]")
#        final_output.append("[boo] [bos]" + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls] [grp] " + 
#                          str(dev_csv.loc[[i]]["group"].values[0]) + " [ste] " + 
#                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoo]")   
        # Case 1: given post and offensiveness, generate implication and group
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" 
                           + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [eoi]")
        final_output.append("[boo] " + " [grp] " + 
                          str(dev_csv.loc[[i]]["group"].values[0]) + " [ste] " + 
                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoo]")
        # Case 2: given post and group, generate implication and offensiveness
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [grp] " + 
                          str(dev_csv.loc[[i]]["group"].values[0]) + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [ste] " + 
                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoo]")
        # Case 3: given post and implication, generate group and offensiveness
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [ste] " + 
                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
                          str(dev_csv.loc[[i]]["group"].values[0]) + " [eoo]")
        # Case 4: regular
        final_input.append("[boi] " + "[bos] " + str(dev_csv.loc[[i]]["post"].values[0]) + " [cls]" + " [eoi]")
        final_output.append("[boo] " + str(dev_csv.loc[[i]]["offensiveYN"].values[0]) + " [grp] " + 
                          str(dev_csv.loc[[i]]["group"].values[0]) + " [ste] " + 
                          str(dev_csv.loc[[i]]["implications"].values[0]) + " [eoo]")

# %%
full_scramble_df = pd.DataFrame()

# %%
full_scramble_df["input"] = final_input
full_scramble_df["output"] = final_output

# %%
full_scramble_df
# Out:
#                                                    input  \
# 0      [boi] [bos] There are too many costas in this ...
# 1      [boi] [bos] There is way too many m0ng0l0id ki...
# 2      [boi] [bos] I called my brother a twat and my ...
# 3      [boi] [bos] the worst of them are the taaaaaaa...
# 4      [boi] [bos] the worst of them are the viruses ...
# ...                                                  ...
# 53118  [boi] [bos] : at least 60 white south africans...
# 53119        [boi] [bos] i'm white thank god [cls] [eoi]
# 53120  [boi] [bos] trump : i wouldn't accept cruz end...
# 53121  [boi] [bos] trump is a moderate . we need more...
# 53122  [boi] [bos] it's okay they can call him a blac...
#
#                         output
# 0           [boo] [OffN] [eoo]
# 1      [boo] [OffY][ind] [eoo]
# 2           [boo] [OffN] [eoo]
# 3      [boo] [OffY][ind] [eoo]
# 4           [boo] [OffN] [eoo]
# ...                        ...
# 53118       [boo] [OffN] [eoo]
# 53119       [boo] [OffN] [eoo]
# 53120       [boo] [OffN] [eoo]
# 53121       [boo] [OffN] [eoo]
# 53122       [boo] [OffN] [eoo]
#
# [53123 rows x 2 columns]

# %%
full_scramble_df.to_csv("SBIC.dev.scramble.4.csv", index=False)

# %% [markdown]
# # Reading in 50/50 data

# %%
import pandas as pd
preds = pd.read_csv("predictions_3_pt3.csv", index_col=0)

# %%
preds["Source Text"] = preds["Source Text"].apply(lambda x: x.replace("[boi] ", "")).apply(lambda x: x.replace(" [eoi]", ""))

preds["Generated Text"] = preds["Generated Text"].apply(lambda x: x.replace("<pad> ", "")).apply(lambda x: x.replace(" <pad>", ""))
preds.columns = ["post", "output"]

# %%
pd.set_option('display.width', 1000)
preds["output"].tolist()
# Out:
# ['[boo] [bos] What do you call a black kid in a car? A shit truck. [cls] [boo]',
#  '[boo] [bos] What do you call a black person in a car? A shit truck [cls] [boo] blacks are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] Africans,black folks,black folks, asian folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks,black folks, asian folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks, native american/first nation folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks,',
#  '[boo] [bos] What do you call a black person with Downs syndrome? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with Downs syndrome? A shit [cls] [boo] black people are a joke [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  "[boo] [bos] What's the difference between a Jew and a pizza? One doesn't scream when you put it in the oven. [cls] [boo]",
#  "[boo] [bos] What's the difference between a Jew and a pizza? One doesn't scream when you put it in the oven. [cls] [boo] jews are bad. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] jewish folks [ste] jewish folks are a waste [ste]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  "[boo] [bos] What's the difference between a priest and a priest? One doesn't scream when the other doesn't scream when a priest screams [cls] [boo]",
#  "[boo] [bos] What's the difference between a priest and a priest? One doesn't scream when the other doesn't scream when a priest screams [cls] [boo] catholic priests are pedophiles [eoo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [ste]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] RT @soossssss: RT @soossssss: RT @soosssssss: RT @soosssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss. [cls] [boo] lesbians are liars. [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] lesbian women [ste] lesbian women are inferior [eoo]',
#  '[boo] [bos] What do you call a ethiopian with a shit? A shit [cls] [boo]',
#  "[boo] [bos] What's the difference between a Ethiopian and a shit? One doesn't cry when you put a shit in it [cls] [boo] ethiopians are poor [eoo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] Ethiopian,Ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black, ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,black, ethiopian,black, asian, asian, asian, asian, asian, asian, asian, asian, asian, asian, asian, asian, asian, asian, asian, asian, ethiopian, asian, ethiopian, asian, ethiopian, asian, ethiopian, asian, ethiopian, asian, ethiopian, asian, latino, latino, latino, latino, latino, latino, native american, native american, native american, latino, native american, native american, latino, native american, native american, latino, native american, native american, latino, native american, native american, latino, native american, latino, native american, latino, native american, latino, native american, latino, native american, latino, native american, latino, native american, latino, native american, latino, native american,',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  '[boo] [boo] [boo] asian folks [ste] asian folks are all terrorists [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are inferior [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are tampons [eoo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are hoes [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are sex objects [eoo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [bos] What do you call a black person with a swollen nose? A swollen nose. [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  "[boo] [bos] What's the difference between a jew and a shit? The shit doesn't scream when you put it in the oven. [cls] [boo]",
#  "[boo] [bos] What's the difference between a jew and a shit? One is a shit [cls] [boo] jews are a joke [eoo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] jewish folks [ste] jewish folks are a waste [ste]',
#  "[boo] [bos] What's the difference between a jew and a satalian? The satalian is a satalian [cls] [boo]",
#  "[boo] [bos] What's the difference between a jew and a pizza? A pizza doesn't scream when you put it in the oven. [cls] [boo] jewish people are bad. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] jewish folks [ste] jewish folks are liars [eoo]',
#  '[boo] [bos] What do you call a feminist with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a feminist with a shit? A shit [cls] [boo] feminists are shit [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] Feminists,feminists,women, lesbian women, lesbian women, trans women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women, bisexual women,',
#  '[boo] [boo] [boo] women [ste] women are dirty [ste]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are dirty [ste]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [ste]',
#  '[boo] [boo] [boo] mass shooting victims [ste] trivializes harm to victims [ste]',
#  '[boo] [boo] [boo] asian folks [ste] asian folks are a waste [ste]',
#  '[boo] [boo] [boo] women [ste] women are bitches [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are sex objects [ste]',
#  '[boo] [boo] [boo] women [ste] women are hoes [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [boo] [boo] women [ste] women are sex objects [ste]',
#  '[boo] [boo] [boo] terrorism victims [ste] trivializes harm to victims [ste]',
#  '[boo] [boo] [boo] terrorism victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are animals [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [boo] [boo] mass shooting victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] What do you call a short man with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a short man with a shit? A shit [cls] [boo] shorts are a joke [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [bos] What do you call a Chinese girl with a swollen nose? A squirter [cls] [boo]',
#  '[boo] [bos] What do you call a Chinese girl with a swollen nose? A squirter [cls] [boo] asian folks are squirter [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] asian folks [ste] asian folks vote when they have an erection [ste]',
#  '[boo] [bos] RT @soosssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss sluts and sexists have sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex is sexist ',
#  "[boo] [bos] Whites are like a shit, they are like a shit, they are like a shit, they are like a shit, they are like a shit, they are like a shit, they are like a shit, they are like a shit, they are like a shit, they are like a shit, they are like a shithole, a shithole, and a shit, and they are shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, and they are like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're like shit, they're",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [boo] [boo]',
#  '[boo] [boo] [boo] women [ste] women are fetus [eoo]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [boo] [boo] black folks [ste] black folks are a waste [ste]',
#  "[boo] [bos] What's the difference between a muslim and a plane? One can run faster than the other can run faster [cls] [boo]",
#  '[boo] [bos] What do you call a Muslim with a shit? A shit [cls] [boo] muslims are terrorists [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] muslim folks [ste] muslim folks are terrorists [ste]',
#  "[boo] [bos] What's the difference between a Jew and a ash? Ash doesn't scream when you put the ash in the oven [cls] [boo]",
#  "[boo] [bos] What's the difference between a Jew and a pizza? One doesn't scream when you put it in a pizza. [cls] [boo] jews are bad. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] jewish folks [ste] jewish folks are bad [ste]',
#  '[boo] [bos] What do you call a black person with a swollen nose? A swollen nose. [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [boo] [boo] liberals [ste] liberals are a waste [ste]',
#  '[boo] [bos] What do you call a black father? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [ste]',
#  '[boo] [boo] [boo] liberals [ste] liberals are stupid [ste]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are sexist [ste]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [boo] [boo]',
#  '[boo] [boo] [boo]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] RT @soosssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss sluts and sexists have sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex. [cls] [boo]',
#  '[boo] [bos] RT @soosssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss sluts and sexists have sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex with sex. [cls] [boo] liberals are liars. [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, black folks, muslim folks, terrorism, black folks, terrorism, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, muslim folks, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, terrorism, terrorism, black folks, muslim folks, muslim folks, terrorism, black folks, terrorism, terrorism, terrorism, black folks, muslim folks, muslim folks, terrorism, black folks, terrorism, terrorism, terrorism, black folks, terrorism, terrorism, terrorism, black folks, terrorism, terrorism, terrorism, black folks, terrorism, terrorism, terrorism, black folks, terrorism, terrorism, terrorism, black folks, muslim folks, terrorism, terrorism, black folks, terrorism, terrorism, terrorism, black folks, muslim folks, terrorism, terrorism, terrorism, black folks, terrorism, terrorism, terrorism, black folks, muslim folks, terrorism, terrorism, terrorism, black folks, terrorism, terrorism, terrorism, black folks',
#  '[boo] [boo] [boo] women [ste] women are sex objects [ste]',
#  '[boo] [boo] [boo] immigrants [ste] immigrants are a burden [ste]',
#  '[boo] [bos] What do you call a bunch of disabled people in a car? Vegetables [cls] [boo]',
#  '[boo] [bos] What do you call a bunch of disabled people in a car? A shit [cls] [boo] disabled people are a joke [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] physically disabled folks [ste] disabled folks are vegetables [eoo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  "[boo] [bos] What's the difference between a Jew and a pizza? A pizza doesn't scream when you put it in the oven. [cls] [boo]",
#  "[boo] [bos] What's the difference between a Jew and a pizza? One doesn't scream when you put it in a pizza. [cls] [boo] jews are bad. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] jewish folks [ste] jewish folks are dirty [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [boo] [boo] women [ste] women are sex objects [ste]',
#  "[boo] [bos] What's the difference between a kike and a kike? One is a kike [cls] [boo]",
#  "[boo] [bos] What's the difference between a jew and a pizza? A pizza doesn't scream when you put it in the oven. [cls] [boo] jewish people are bad. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] liberals [ste] liberals are stoopers [eoo]',
#  '[boo] [boo] [boo] women [ste] women are sex objects [ste]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are bitches [ste]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [ste]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are n*ggers [eoo]',
#  '[boo] [bos] What do you call a black woman with a swollen nose? A swollen nose. [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] African folks,black folks,black folks, asian folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks, native american/first nation folks,black folks, latino/latina folks,women, latino/latina folks,women, latino/latina folks, native american/first nation folks, latino/latina folks, native american/first nation folks, latino/latina folks, native american/first nation folks, latino/latina folks, native american/first nation folks, latino/latina folks, native american/first nation folks, latino/latina folks, native american/first nation folks, native american/first nation folks, latino/latina folks, native american/first nation folks,women, native american/first nation folks, native american/first nation folks, latino/latina folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, native american/first nation folks, latino/latina folks, native american/first nation folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks, native american/first nation folks,black folks, native american/first nation folks, native american/first nation folks,black folks,black folks, native american/first nation folks, native american/first nation folks,black folks,black folks, native american/first nation folks, native american/first nation folks,black folks,black',
#  '[boo] [boo] [boo]',
#  "[boo] [bos] What's the difference between a pregnant woman and a dishwasher? One doesn't cry when you put the dishwasher in it. [cls] [boo]",
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are sex objects [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] What do you call a black kid with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [boo] [boo] women [ste] women are bitches [ste]',
#  '[boo] [boo] [boo] rape victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [bos] What do you call a black person with a black eye? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] RT @soossssssssss: @soossssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss &#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&',
#  '[boo] [bos] The sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the obama bb savages sex with the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] gay men,lesbian women, gay men,lesbian women, gay men, trans women, trans men, bisexual women, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, trans women, trans men, bisexual women, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men, bisexual men',
#  '[boo] [boo] [boo] women [ste] women are objects [eoo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are less than women [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are sex objects [eoo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are poor [ste]',
#  '[boo] [bos] What do you call a nigga? A nigga [cls] [boo]',
#  '[boo] [bos] What do you call a black man with a shit? A shit [cls] [boo] black folks are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are stupid [eoo]',
#  '[boo] [bos] What do you call a bunch of retarded people in a car? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a bunch of retarded people in a car? A shit [cls] [boo] retarded people are a joke [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] mentally disabled folks [ste] mentally disabled folks are vegetables [eoo]',
#  '[boo] [bos] What do you call a bunch of disabled people in a car? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a bunch of disabled people in a car? A shit [cls] [boo] disabled people are a joke. [boo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] physically disabled folks [ste] disabled folks are inferior [eoo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  "[boo] [bos] I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist. [cls] [boo]",
#  "[boo] [bos] I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist, I'm not racist. [cls] [boo] blacks are inferior. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] What do you call a Mexican with a shit? A shit. [cls] [boo]',
#  '[boo] [bos] What do you call a Mexican with a fat shit? A shit [cls] [boo] latinos are fat [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] latino/latina folks [ste] latino folks are fat [ste]',
#  '[boo] [boo] [boo] women [ste] women are stupid [eoo]',
#  "[boo] [bos] What's the difference between a catholic priest and a trash bag? One doesn't scream when you put the trash in it. [cls] [boo]",
#  "[boo] [bos] What's the difference between a catholic priest and a pizza? One doesn't scream when you put a pizza in it. [cls] [boo] catholic priests are pedophiles. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] christian folks [ste] christian folks are trash [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are bitches [ste]',
#  "[boo] [bos] What's the difference between a jew and a pizza? A pizza doesn't scream when you put it in the oven. [cls] [boo]",
#  "[boo] [bos] What's the difference between a jew and a pizza? A pizza doesn't scream when you put it in the oven. [cls] [boo] jewish people are bad. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] jewish folks [ste] jewish folks are inferior [ste]',
#  '[boo] [bos] What do you call a black person with a shit? A murderer [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  '[boo] [boo] [boo] old folks [ste] old folks are lazy [ste]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [boo] [boo] ethiopians [ste] ethiopians are anti-semite [ste]',
#  '[boo] [boo] [boo]',
#  "[boo] [bos] What's the difference between a jew and a pizza? A pizza doesn't scream when you put it in the oven. [cls] [boo]",
#  "[boo] [bos] What's the difference between a jew and a pizza? A pizza doesn't scream when you put it in the oven. [cls] [boo] jewish people are bad. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] jewish folks [ste] jewish folks are greedy [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] What do you call a retarded person? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a bunch of mentally disabled people in a car? A shit [cls] [boo] mentally disabled people are a joke. [boo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] jewish folks [ste] jewish folks are the retards [ste]',
#  '[boo] [bos] What do you call a gay sex cock? A sex cock [cls] [boo]',
#  "[boo] [bos] What's the difference between a gay sex and a sex slave? The sex slave doesn't scream when you put the sex slave in the mouth. [cls] [boo] gay people are sex slaves. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] lesbian women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans women, trans men, trans men, trans men, trans, trans, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men, trans men',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are hoes [ste]',
#  '[boo] [bos] What do you call a black person with a shit? A monkey. [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  '[boo] [boo] [boo] christian folks [ste] christian folks are pedophiles [ste]',
#  "[boo] [bos] What's the difference between a Muslim and a bomb? One is a bomb [cls] [boo]",
#  '[boo] [bos] What do you call a Muslim with a shit? A shit [cls] [boo] muslims are terrorists [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] muslim folks [ste] muslim folks are violent [eoo]',
#  '[boo] [bos] What do you call a black jew? A savage [cls] [boo]',
#  '[boo] [bos] What do you call a black jew? A shit [cls] [boo] black people are lesser [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] jewish folks [ste] jewish folks are a waste [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [boo] [boo] asian folks [ste] asian folks are bad [ste]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  '[boo] [boo] [boo] folks with mental illness/disorder [ste] mental illness is funny [eoo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are weak [ste]',
# ...
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  "[boo] [bos] What's the difference between a black jew and a ashy jew? The ashy jews get a ashy ashy ash [cls] [boo]",
#  "[boo] [bos] What's the difference between a black jew and a black jew? One is black and the other is black. [cls] [boo] black people are inferior. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] jewish folks [ste] jewish folks are ash [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  "[boo] [bos] What's the difference between a gay man and a fruit? One doesn't scream when you put it in the oven. [cls] [boo]",
#  "[boo] [bos] What's the difference between a gay man and a freezer? One doesn't fart when you put a freezer in it [cls] [boo] gay men are a waste [eoo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] gay men [ste] gay men are fruity [eoo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are negroes [eoo]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [boo] [boo] swedish folks [ste] swedish folks are a waste [ste]',
#  '[boo] [bos] RT @soossssssss: RT @soossssssss: RT @soosssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss sexiest bitch [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are bitches [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are niggers [ste]',
#  '[boo] [bos] What do you call a black person with a shit? A monkey. [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are gorillas [ste]',
#  '[boo] [bos] What do you call a Chinese girl with a swollen nose? A squirter. [cls] [boo]',
#  '[boo] [bos] What do you call a Chinese girl with a swollen nose? A squirter [cls] [boo] asian folks are squirter [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] asian folks [ste] asian folks bark [ste]',
#  '[boo] [bos] What do you call a sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex with a savages and a sex with a sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex sex s sex s sex s sex s sex s s o s s o s s o s s o s s o s s o s s o s s s s o s s s o s s s o s s o s s o s s o s s o s s o s s o s s o s s o s s o s s o s s o s s o s s',
#  '[boo] [bos] What do you call a bunch of autistic kids with Downs Syndrome? A shit [cls] [boo] autistic kids are a joke [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] folks with mental illness/disorder [ste] are emo [ste]',
#  '[boo] [bos] What do you call a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a b a b a s a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a shit shit on a',
#  '[boo] [bos] What do you call a shit on a shit on a shit on a shit? A shit on a shit on a shit. [cls] [boo] ethiopians are poor. [boo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] Ethiopian,Ethiopian,Ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,ethiopian,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,black,ethiopian,ethiopian,ethiopian,ethiopian,black,black,black, ethiopian,black, ethiopian,black, ethiopian,black, ethiopian,black, asian, latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino, latino, latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latino,latin',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [eoo]',
#  '[boo] [bos] What do you call a Mexican with a shit? A terrorist [cls] [boo]',
#  '[boo] [bos] What do you call a bunch of immigrants in a mexican country? A muslim. [cls] [boo] muslims are terrorists. [boo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] immigrants [ste] immigrants are dumb [eoo]',
#  '[boo] [bos] What do you call a black person in a trash bin? A trash bin. [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are dirty [ste]',
#  "[boo] [bos] What's the difference between a priest and a pizza? A pizza doesn't scream when you put it in the oven. [cls] [boo]",
#  "[boo] [bos] What's the difference between a priest and a pizza? A pizza doesn't scream when you put it in a pizza. [cls] [boo] priests are a joke. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] christian folks [ste] christian folks are pedophiles [ste]',
#  '[boo] [boo] [boo] egyptian [boo] egyptian folks are all egyptian [eoo]',
#  '[boo] [bos] What do you call a woman with down syndrome who has no legs? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a woman with down syndrome who has no mental illness? A sex shit [cls] [boo] mentally disabled folks are a burden [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] mentally disabled folks [ste] mentally disabled folks are a burden [ste]',
#  '[boo] [boo] [boo] women [ste] women are sex objects [ste]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  "[boo] [bos] What's the difference between a black man and a shit? One doesn't cry when you scream a shit. [cls] [boo] black people are a joke. [boo]",
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are lazy [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  '[boo] [boo] [boo] women [ste] women are sex objects [ste]',
#  '[boo] [boo] [boo] assault victims [ste] trivializes harm to victims [eoo]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are criminals [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are dark [ste]',
#  '[boo] [bos] What do you call a sex retarded kid with Down syndrome? A sex retarded kid [cls] [boo]',
#  '[boo] [bos] What do you call a bunch of retarded people in a car? A shit [cls] [boo] retarded people are a joke [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] folks with mental illness/disorder [ste] folks with mental illness/disorder are a joke. [ste]',
#  '[boo] [bos] What do you call a black dad? A deadbeat [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [bos] What do you call a bunch of disabled people in a car? Vegetables [cls] [boo]',
#  '[boo] [bos] What do you call a bunch of disabled people in a car? A shit [cls] [boo] disabled people are a joke. [boo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are vegetables [ste]',
#  '[boo] [boo] [boo] folks with mental illness/disorder [ste] mental illness is funny [eoo]',
#  '[boo] [boo] [boo]',
#  '[boo] [boo] [boo] immigrants [ste] immigrants are criminals [ste]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are niggers [ste]',
#  '[boo] [bos] What do you call a redneck in a Texas home? A Texas home [cls] [boo]',
#  '[boo] [bos] What do you call a bunch of Texasans in a car? A shit [cls] [boo] shit in the streets of Texas [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] mass shooting victims [ste] mass shooting victims are a joke [eoo]',
#  '[boo] [boo] [boo] men [ste] men are misandry [eoo]',
#  '[boo] [boo] [boo]',
#  '[boo] [bos] RT @soossssssss: RT @soosssssssss: RT @soossssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss sexiest bitch [cls] [boo]',
#  '[boo] [bos] I like my women like I like my coffee Ground up and in the freezer [cls] [boo] women are only good for sex [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] women [ste] women are hoes [ste]',
#  '[boo] [boo] [boo] women [ste] women are bitches [ste]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo]',
#  '[boo] [bos] What do you call a black person with a shit? A shit [cls] [boo] black people are criminals [eoo]',
#  '[boo] [bos]What do you call a black person with a swollen nose? A swollen nose. [cls] [boo] black folks [ste] black folks are inferior. [ste]',
#  '[boo] [boo] [boo] black folks [ste] black folks are inferior [eoo]',
#  '[boo] [bos] The Left has a slur against the Left and is a slur against the Left and is a slur against the Left and is a slur against the Left and is a slur against the Left and is a slur against the Left and is a slur against the Left and is a slur against the Left and is a slur against the Left and is a sluts [cls] [boo]',
#  '[boo] [bos] The sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the obama bb sass sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the sex of the']

# %% [raw]
# from sklearn.metrics import f1_score
# import re
# list_of_data = []
# preds = preds["output"]
# # split on parenthesis
# for i in range(0, len(preds)):
#     list_of_data.append(list(filter(lambda x: x != "", [sentence.strip() for sentence in
#                                                 preds[i].replace("<pad>", '').replace("[", '').replace("boo",'')
#                                                 .replace("grp", '').replace("ste", '').replace("eoo", '')
#                                                 .split(']')])))

# %%
y_test = pd.read_csv("SBIC.v2.agg.dev.csv", index_col=0)[:1000]
y_test

# %%
merged_df = pd.merge(preds, y_test, on="post")
merged_df["offensiveYN"] = merged_df["offensiveYN"].apply(lambda label: 1 if label == 1 else 0)

# %%
merged_df["offYNPredictions"] = merged_df["output"].apply(lambda label: 1 if "OffY" in label else 0)

# %%
subset_merged_df = merged_df[["output", "targetMinority", "targetCategory", "targetStereotype", "offensiveYN"]]
subset_merged_df[merged_df.output.str.contains('OffY')].head(50)
